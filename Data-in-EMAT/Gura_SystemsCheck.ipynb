# %% [markdown]
# # A first-level heading
# ## A second-level heading
# ### A third-level heading
#
# **Bold Text**
#
# 1. First item
# 2. Second item
# 3. Third item
#
# _Italic Text_
#
# ![Kent State Image](https://www-s3-live.kent.edu/s3fs-root/s3fs-public/styles/normal_banner/public/administrative-group/landingpage.jpg?VersionId=RZ6c.mVx1ChAS8muTVaD5eLtox8rElWt&h=e6f36a9c&itok=7_DmWltL)

# %%
def returnFunction(passedVar):
    return passedVar

temp_var = "Variable"

print("Hello World!\n")

for x in range(5):
  print("This message is printed 5 times\n")

print(returnFunction("String to be returned\n"))
# Out:
# Hello World!
#
# This message is printed 5 times
#
# This message is printed 5 times
#
# This message is printed 5 times
#
# This message is printed 5 times
#
# This message is printed 5 times
#
# String to be returned
